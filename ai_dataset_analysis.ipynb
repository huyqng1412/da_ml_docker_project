# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"work/ai_course_data.csv", encoding='utf-8', index_col=False)
data.head(5)
# Out:
#    Student Id  Quiz_1  Midterm_1  Assignment_1  Assignment_2  Assignment_3  \
# 0           1    2.34       6.78          4.56          3.24          4.56
# 1           2    8.17      12.43          2.87          1.87          2.89
# 2           3    5.92       3.21          0.45          4.56          0.76
# 3           4    1.45       9.87          3.12          2.34          3.01
# 4           5    9.78       5.34          0.98          0.98          1.98
#
#    Project  Presentation  Final_Exam_Marks  Total Grade   Categories
# 0     5.67          7.89              24.0  59.04    C+         Pass
# 1     2.34          2.34              29.0  61.91    B-        Pass
# 2     8.90          5.67              30.0  59.47    C+         Pass
# 3     1.23          1.23              33.0  55.25    C+         Pass
# 4     9.45          9.01              31.0  68.52     B  Distinction
